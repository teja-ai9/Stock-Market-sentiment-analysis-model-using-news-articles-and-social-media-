# %%
#pip install nsepy

# %% [markdown]
# ### https://nsepy.xyz/
#
#
#
#
# ### https://aeron7.github.io/nsepython/documentation/nsefetch.html#basic-usage

# %%
from nsepy import get_history
from datetime import date

data = get_history(symbol="RELIANCE", start=date(2022,1,1), end=date(2022,12,31))

data
# Out:
#               Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2022-01-03  RELIANCE     EQ     2368.15  2365.00  2407.95  2363.55  2407.95
# 2022-01-04  RELIANCE     EQ     2403.85  2415.90  2461.00  2404.00  2460.00
# 2022-01-05  RELIANCE     EQ     2458.10  2462.00  2477.00  2432.95  2461.85
# 2022-01-06  RELIANCE     EQ     2469.60  2451.20  2454.00  2409.00  2419.15
# 2022-01-07  RELIANCE     EQ     2416.50  2430.95  2458.05  2411.55  2439.90
# ...              ...    ...         ...      ...      ...      ...      ...
# 2022-12-26  RELIANCE     EQ     2502.20  2514.75  2542.00  2492.40  2525.00
# 2022-12-27  RELIANCE     EQ     2524.05  2530.00  2548.80  2515.25  2542.70
# 2022-12-28  RELIANCE     EQ     2544.70  2538.00  2549.80  2521.50  2542.00
# 2022-12-29  RELIANCE     EQ     2544.45  2527.00  2548.90  2525.50  2544.95
# 2022-12-30  RELIANCE     EQ     2543.30  2545.10  2577.00  2541.10  2547.00
#
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd

# %%
data.to_csv("NSE_Reliance.csv")
